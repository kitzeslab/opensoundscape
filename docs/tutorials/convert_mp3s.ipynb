# %%
from pathlib import Path
import subprocess

# %%
folder = Path("/Users/louifh/Dev/opensoundscape/docs/tutorials/great_plains_toad_dataset/")

# %%
files = folder.glob("*.mp3")
for file in files:
    print(file)
    name = file.stem
    subprocess.run(["ffmpeg", 
                    "-i", f"{file}", f"{name}.wav"])
# Out:
# /Users/louifh/Dev/opensoundscape/docs/tutorials/great_plains_toad_dataset/pops1.mp3
# /Users/louifh/Dev/opensoundscape/docs/tutorials/great_plains_toad_dataset/gpt4.mp3
# /Users/louifh/Dev/opensoundscape/docs/tutorials/great_plains_toad_dataset/pops2.mp3
# /Users/louifh/Dev/opensoundscape/docs/tutorials/great_plains_toad_dataset/gpt1.mp3
# /Users/louifh/Dev/opensoundscape/docs/tutorials/great_plains_toad_dataset/gpt0.mp3
# /Users/louifh/Dev/opensoundscape/docs/tutorials/great_plains_toad_dataset/negative9.mp3
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with Apple clang version 13.0.0 (clang-1300.0.29.3)
# ...
